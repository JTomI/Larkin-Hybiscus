# %%
import CMOS_Plot_Tools as cpt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
plt.rcParams["figure.figsize"] = (12,9)
cmap='Spectral'
from tqdm import tqdm
import itertools

# %%
def Edge_Finder1D(Array1D=None):
    """Finds the two endpoints of a 1D array with boolean entries."""
    lims = []
    flipper = True
    for i in range(len(Array1D)):
        if Array1D[i] == flipper:
            lims.append(i)
            flipper=not flipper
    return lims

def Get_Cropped(chamber_image=None,thresh=.00005):
    """Find the uFluidic chamber edges in an impedance image using a chosen threshold values, and returns an image cropped to those edges."""
    [phase1,phase2]=F0167.Get_Data(index=0) #change to self.get data in CPT
    avphase = (phase1+phase1)/2
    av_xlinecut,av_ylinecut = np.mean(avphase,axis=0),np.mean(avphase,axis=1)
    xcrop1D,ycrop1D = (av_xlinecut>thresh),(av_ylinecut>thresh)
    ([xlim1,xlim2],[ylim1,ylim2])= Edge_Finder1D(xcrop1D),Edge_Finder1D(ycrop1D)
    return chamber_image[ylim1:ylim2,xlim1:xlim2]

# %%
fname = r"C:\Users\jtincan\Documents\minerva_data\F0167_01272022\F0167_01272022.h5"
F0167=cpt.CPT(data_path=fname)
# Out:
# Impedance Image Phases:  ['image_2d_ph1', 'image_2d_ph2']

# %%
[phase1,phase2]=F0167.Get_Data(index=1000)
avphase = (phase1+phase1)/2
cropped_phase = Get_Cropped(chamber_image=avphase)
fig, ax_main = plt.subplots()
im = ax_main.imshow(cropped_phase,cmap=cmap)
ax_main.set_xlabel("x [pix]")
ax_main.set_ylabel("y [pix]")
ax_main.set_title("Cropped Impedance Image (ph1+ph2)/2")
# Out:
# Text(0.5,1,'Cropped Impedance Image (ph1+ph2)/2')

# %% [markdown]
# # Testing the image used for determining the crop bounds

# %%
[phase1,phase2]=F0167.Get_Data(index=0)
avphase = (phase1+phase1)/2
av_xlinecut = np.mean(avphase,axis=0)
av_ylinecut = np.mean(avphase,axis=1)

fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(15,7.5))
# for i in range(avphase.shape[0]):
#     axs[0].plot(avphase[i,:],alpha=.15)
# for i in range(avphase.shape[1]):
#     axs[1].plot(avphase[:,i],alpha=.15)
    
axs[0].plot(av_xlinecut,'black',label="Averaged X-Linecuts")
axs[0].set_xlabel('x [pix]')
axs[0].set_ylim(bottom=-.0001)

axs[1].plot(av_ylinecut,'black',label="Averaged Y-Linecuts")
axs[1].set_xlabel('y [pix]')
axs[1].set_ylim(bottom=-.0001)

axs[0].set_ylabel('Impedance [a.u.]',fontsize=16)
axs[1].set_ylabel('Impedance [a.u.]',fontsize=16)
axs[0].legend()
axs[1].legend()
xcrop,ycrop = (av_xlinecut>.00005) , (av_ylinecut>.00005)
xycrop = np.outer(ycrop,xcrop)

fig, ax_main = plt.subplots(nrows=1,ncols=2,figsize=(15,7.5))
im = ax_main[0].imshow(avphase,cmap=cmap)
ax_main[0].set_xlabel("x [pix]")
ax_main[0].set_ylabel("y [pix]")
# fig.colorbar(im,ax=ax_main[0])
ax_main[0].set_title("Reference Image for Crop (ph1+ph2)/2")

ax_main[1].imshow(xycrop)
ax_main[1].set_xlabel("x [pix]")
ax_main[1].set_ylabel("y [pix]")
ax_main[1].set_title("Chamber Crop Region")
plt.show()
